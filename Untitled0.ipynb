# %% [markdown]
# <a href="https://colab.research.google.com/github/koularya/koularya/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

data = {
    "Energy Source": ["Solar", "Wind", "Hydropower", "Geothermal", "Biomass", "Nuclear"],
    "Energy Consumption (Mwh)": [1200,np.nan,2500,np.nan,2500,3200],
    "Cost (Million $)": [200,400,np.nan,150,250,np.nan]
}

energy_df = pd.DataFrame(data)

print("Original Energy Data With Missing Values:")
print(energy_df)
# Out:
# Original Energy Data With Missing Values:
#   Energy Source  Energy Consumption (Mwh)  Cost (Million $)
# 0         Solar                    1200.0             200.0
# 1          Wind                       NaN             400.0
# 2    Hydropower                    2500.0               NaN
# 3    Geothermal                       NaN             150.0
# 4       Biomass                    2500.0             250.0
# 5       Nuclear                    3200.0               NaN

# %%
scaler = MinMaxScaler()

energy_df[["Energy Consumption (Mwh)"]] = scaler.fit_transform(energy_df[["Energy Consumption (Mwh)"]])
energy_df[["Cost (Million $)"]] = scaler.fit_transform(energy_df[["Cost (Million $)"]])


print("\nNormalized Energy Data:")
print(energy_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-16343141.py in <cell line: 0>()
# ----> 1 scaler = MinMaxScaler()
#       2
#       3 energy_df[["Energy Consumption (Mwh)"]] = scaler.fit_transform(energy_df[["Energy Consumption (Mwh)"]])
#       4 energy_df[["Cost (Million $)"]] = scaler.fit_transform(energy_df[["Cost (Million $)"]])
#       5
#
# NameError: name 'MinMaxScaler' is not defined
