# %% [markdown]
# <a href="https://colab.research.google.com/github/koularya/koularya/blob/main/Copy_of_scatter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
df = pd.read_csv('/content/appliance_energy.csv')
df.head()
# Out:
#    Temperature (°C)  Energy Consumption (kWh)
# 0         22.490802                  2.292604
# 1         34.014286                  3.251925
# 2         29.639879                  3.009868
# 3         26.973170                  1.703533
# 4         18.120373                  1.702201

# %%
df.tail()
# Out:
#     Temperature (°C)  Energy Consumption (kWh)
# 95         24.875912                  2.079686
# 96         25.454657                  2.506915
# 97         23.550820                  2.525658
# 98         15.508383                  1.689184
# 99         17.157829                  2.129374

# %%
df.describe()
# Out:
#        Temperature (°C)  Energy Consumption (kWh)
# count        100.000000                100.000000
# mean          24.403615                  2.439821
# std            5.949788                  0.693527
# min           15.110442                  0.978107
# 25%           18.864015                  1.908640
# 50%           24.282849                  2.364121
# 75%           29.604062                  2.931199
# max           34.737739                  4.159094

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Temperature (°C)          100 non-null    float64
#  1   Energy Consumption (kWh)  100 non-null    float64
# dtypes: float64(2)
# memory usage: 1.7 KB

# %%
df.isnull().sum()
# Out:
# Temperature (°C)            0
# Energy Consumption (kWh)    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Temperature (°C)', 'Energy Consumption (kWh)'], dtype='object')

# %%
plt.scatter(df['Temperature (°C)'], df['Energy Consumption (kWh)'])
plt.xlabel('Temperature (°C)')
plt.ylabel('Energy Consumption (kWh)')
plt.title('Temperature vs Energy Consumption')

plt.show()

# %%
x = df[['Temperature (°C)']]
y = df['Energy Consumption(kWh)']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Energy Consumption(kWh)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-124368193.py in <cell line: 0>()
#       1 x = df[['Temperature (°C)']]
# ...

# %%
sns.heatmap(df)

# %%
import seaborn as sns
sns.pairplot(df)
plt.show()

# %%
sns.boxplot(df)
plt.show()

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-111805659.py in <cell line: 0>()
# ----> 1 x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
#
# NameError: name 'y' is not defined

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-690721473.py in <cell line: 0>()
#       1 model=LinearRegression()
# ----> 2 model.fit(x_train,y_train)
#
# NameError: name 'x_train' is not defined

# %%
x = df[['Temperature (°C)']]
y = df['Energy Consumption(kWh)']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Energy Consumption(kWh)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3077786559.py in <cell line: 0>()
#       1 x = df[['Temperature (°C)']]
# ...

# %%
mse = mean_squared_error(y_test, y_pred)
print(f"mean squared error:")
r2 = r2_score*(y_test, y_pred)*100

# %%
plt.scatter(x_test,y_test,color='blue',label='Test Data')
plt.plot(x_test,y_pred,color='green',label='Train Data')
plt

# %%
import joblib

joblib.dump(model, 'appliance_energy_model.pk1')

['appliance_energy_model.pk1']
# Out:
# ['appliance_energy_model.pk1']
